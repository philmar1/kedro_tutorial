# %%
# Load kedro 
# %load_ext kedro.ipython
# Out:
# [03/11/25 11:22:06] INFO     Using                                                                  ]8;id=577903;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=928558;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-p
#                              ackages/kedro/framework/project/rich_logging.yml' as logging
#                              configuration.
# ...

# %%
# Reload kedro in case you made some changes in nodes or data .. 
# %reload_ext kedro.ipython
# Out:
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=112653;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=317453;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/ipython/__init__.py#61\61]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=74349;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=518299;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/ipython/__init__.py#63\63]8;;\
# ...

# %%
import pandas as pd 

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from matplotlib import pyplot as plt

# %%
winequality_red = catalog.load('red.winequality_scaled')
winequality_white = catalog.load('white.winequality_scaled')
# Out:
# [03/11/25 11:22:15] INFO     Loading data from red.winequality_scaled (CSVDataset)...           ]8;id=192205;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=961935;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from white.winequality_scaled (CSVDataset)...         ]8;id=133867;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=598771;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
winequality_red
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1         -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2         -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3          1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# ...             ...               ...          ...             ...        ...
# 1594      -1.217796          0.403229    -0.980669       -0.382271   0.053845
# 1595      -1.390155          0.123905    -0.877968       -0.240375  -0.541259
# 1596      -1.160343         -0.099554    -0.723916       -0.169427  -0.243707
# ...

# %%
from sklearn.model_selection import train_test_split

def split_train_test(df, test_size=0.2):
    train_cols = [x for x in df.columns if x != 'quality']
    X, y = df[train_cols], df['quality']
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=test_size)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test(winequality_red)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor

class MyRegressor():
    def __init__(self, model_name: str, model_params: dict = {}) -> None:
        self.model_name = model_name
        self.model_params = model_params
        
        if model_name == 'linear_regression':
            self.model = LinearRegression(**model_params)
        if model_name == 'mlp':
            self.model = MLPRegressor(**model_params)
            
        
    def fit(self, X, y):
        return self.model.fit(X, y)

# %%
regressor = MyRegressor('mlp')

# %%
regressor.model
# Out:
# MLPRegressor()

# %%
regressor.model.fit(X_train, y_train)
# Out:
# [03/11/25 11:31:18] WARNING  /Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-pa ]8;id=547746;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/warnings.py\warnings.py]8;;\:]8;id=414985;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/warnings.py#109\109]8;;\
#                              ckages/sklearn/neural_network/_multilayer_perceptron.py:691:
# ...
#                              reached and the optimization hasn't converged yet.
#                                warnings.warn(
# MLPRegressor()

# %%
regressor.model.predict(X_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array([-8.79468486e-01,  1.49903586e-01, -6.85848706e-01,  6.59059292e-02,
#         8.04111798e-01, -6.90782669e-03, -5.92555665e-01,  1.53916770e+00,
#         5.66870934e-01, -1.47906372e-01, -4.30852184e-01, -7.61374914e-01,
#         6.05388621e-01, -2.21501966e-01,  3.06380874e-01, -5.23357903e-01,
#         1.43668619e+00,  1.14902296e-01,  2.32319629e-01, -3.49485674e-01,
#        -1.79387914e-01, -4.91823831e-01,  9.36007337e-01, -1.02070576e-01,
#        -2.54862666e-01,  7.04831770e-01,  1.25861082e+00, -3.14941159e-01,
#         5.16617269e-01,  2.99213768e-01, -1.60921335e-01, -1.18918416e+00,
#        -6.44107453e-01,  8.03114052e-01, -4.73759905e-01,  9.22055332e-01,
#         2.86774560e-01, -9.75229276e-01,  1.53364711e-01, -4.72460940e-02,
#         1.26701612e+00, -6.58118915e-02,  6.93948334e-01, -7.04192634e-01,
# ...

# %%
def load_model(model_name: str, model_params: dict = {}):
    return MyRegressor(model_name, model_params) 

def train_model(regressor_model, X_train, y_train):
    regressor_model.model.fit(X_train, y_train)
    return regressor_model 

def predict(regressor_model, X):
    return regressor_model.model.predict(X)


def plot_metrics(y_true, y_pred, which, model, save_dir=""):
    plt.scatter(y_true, y_pred)
    plt.xlabel('True')
    plt.ylabel('Pred')
    plt.savefig(save_dir + f'cm_{model.model_name}_{which}.png')

# %%
regressor_model = load_model(model_name='mlp')
regressor_model = train_model(regressor_model, X_train, y_train)
y_pred = predict(regressor_model, X_test)

plot_metrics(y_test, y_pred, 'red', regressor_model)
# Out:
# [03/11/25 11:43:44] WARNING  /Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/site-pa ]8;id=339444;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/warnings.py\warnings.py]8;;\:]8;id=568798;file:///Users/philippemartin/miniconda3/envs/to_remove/lib/python3.12/warnings.py#109\109]8;;\
#                              ckages/sklearn/neural_network/_multilayer_perceptron.py:691:
# ...
#                              reached and the optimization hasn't converged yet.
#                                warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
